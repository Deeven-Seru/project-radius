# %% [markdown]
# # SH-WFS Theory
# Derivation of the Center of Gravity slope estimator.
# $$s_x^{(k)} = \frac{f_{\rm lens}}{\lambda} \frac{\partial\phi}{\partial x}\bigg|_k$$

# %%
import numpy as np
print('SH-WFS Theory notebook placeholder')
